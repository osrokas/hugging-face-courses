# %% [markdown]
# ## Creating a Transformer

# %%
from transformers import AutoModel

model = AutoModel.from_pretrained("bert-base-cased")

# %%
model.config

# %%
from transformers import BertModel

model = BertModel.from_pretrained("bert-base-cased")

# %%
model.config

# %%
model.save_pretrained("/home/osrokas/repos/transformers-course/notebooks/models/my_bert_model")

# %%
model = AutoModel.from_pretrained("/home/osrokas/repos/transformers-course/notebooks/models/my_bert_model")

# %%
model.push_to_hub("my-test-model")

# %%
model = AutoModel.from_pretrained("osrokas/my-test-model")
